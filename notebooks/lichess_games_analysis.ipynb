# %%
# Code to generate a main CSV file form all the games from the PGN. Took 5 hours for 2 million games
import chess.pgn
import pandas as pd
import os
from tqdm import tqdm
from multiprocessing import Pool, cpu_count
from io import StringIO
import glob

# Configuration
CHUNK_SIZE = 5000  # Games per CSV file
OUTPUT_DIR = "pgn_chunks"
os.makedirs(OUTPUT_DIR, exist_ok=True)

def process_game(game_str):
    """Process a single game string"""
    try:
        game = chess.pgn.read_game(StringIO(game_str))
        if not game:
            return None
            
        headers = game.headers
        return {
            'Event': headers.get('Event'),
            'White': headers.get('White'),
            'Black': headers.get('Black'),
            'Result': headers.get('Result'),
            'WhiteElo': try_int(headers.get('WhiteElo')),
            'BlackElo': try_int(headers.get('BlackElo')),
            'ECO': headers.get('ECO'),
            'TimeControl': headers.get('TimeControl'),
            'Termination': headers.get('Termination'),
            'Moves': ' '.join(str(move) for move in game.mainline_moves())
        }
    except Exception as e:
        print(f"Error processing game: {e}")
        return None

def try_int(value):
    """Safely convert to integer"""
    try:
        return int(value) if value and str(value).isdigit() else None
    except:
        return None

def process_chunk(chunk, chunk_number):
    """Process and save a single chunk"""
    with Pool(cpu_count()) as pool:
        results = [r for r in pool.map(process_game, chunk) if r is not None]
    
    if results:
        pd.DataFrame(results).to_csv(
            f"{OUTPUT_DIR}/chunk_{chunk_number:04d}.csv",
            index=False
        )
    return len(results)

def process_pgn_file(pgn_path):
    """Main processing function"""
    # First count total games if possible
    total_games = None
    try:
        with open(pgn_path) as temp_file:
            total_games = sum(1 for _ in chess.pgn.scan_headers(temp_file))
    except:
        pass
    
    # Process file in chunks
    chunk_number = 0
    processed_games = 0
    current_chunk = []
    
    with open(pgn_path) as pgn_file, \
         tqdm(desc="Processing PGN", total=total_games, unit="game") as pbar:
        
        while True:
            game = chess.pgn.read_game(pgn_file)
            if game is None:
                if current_chunk:
                    processed_games += process_chunk(current_chunk, chunk_number)
                    chunk_number += 1
                break
                
            exporter = chess.pgn.StringExporter(headers=True, variations=True, comments=True)
            current_chunk.append(game.accept(exporter))
            
            if len(current_chunk) >= CHUNK_SIZE:
                processed_games += process_chunk(current_chunk, chunk_number)
                pbar.update(len(current_chunk))
                current_chunk = []
                chunk_number += 1
    
    # Combine all CSV files
    combined_df = pd.concat(
        [pd.read_csv(f) for f in glob.glob(f"{OUTPUT_DIR}/chunk_*.csv")],
        ignore_index=True
    )
    
    # Save final combined file
    combined_df.to_csv("combined_chess_games.csv", index=False)
    
    # Optionally clean up chunk files
    for f in glob.glob(f"{OUTPUT_DIR}/chunk_*.csv"):
        os.remove(f)
    
    return combined_df

# Usage
df = process_pgn_file(
    "/home/igorreis/Documentos/Python Projects/chess-data-coach/data/lichess_games_05_2025.pgn"
)
print(f"Processed {len(df)} games")
# Out:
# Processing PGN: 2785000game [4:10:55, 184.99game/s]
# Processed 2789900 games

# %%
import pandas as pd

df = pd.read_csv("combined_chess_games.csv")
# Values to exclude
values_to_exclude = ['Abandoned', 'Unterminated', 'Rules infraction']

# Filter rows where column 'B' is NOT in the exclusion list
df = df[(~df['Termination'].isin(values_to_exclude)) & (~df['Moves'].isna()) & (df['Moves'].str.count(" ") > 30)]
sample_df = df.copy()

# %%
import chess
import chess.pgn
import io
import pandas as pd
from tqdm import tqdm
from multiprocessing import Pool, cpu_count
import numpy as np

def get_fen_after_move(args):
    """Process single game with error handling."""
    move_text, move_number = args
    try:
        game = chess.pgn.read_game(io.StringIO(move_text))
        if not game:
            return np.nan
            
        board = game.board()
        for move in game.mainline_moves():
            board.push(move)
            if board.fullmove_number > move_number:
                break
        return board.fen()
    except Exception:
        return np.nan

def batch_process(df, move_number=30, n_workers=None):
    """Parallel processing of FEN extraction."""
    n_workers = n_workers or max(1, cpu_count() - 1)
    args = [(move, move_number) for move in df['Moves']]
    
    with Pool(n_workers) as pool:
        results = list(tqdm(
            pool.imap(get_fen_after_move, args),
            total=len(df),
            desc=f"Extracting FENs after move {move_number}"
        ))
    
    return pd.Series(results, index=df.index)

# Usage (3-5x faster than progress_apply)
sample_df['fen_after_15'] = batch_process(sample_df, move_number=15)
# Out:
# Extracting FENs after move 15: 100%|██████████| 2488096/2488096 [24:46<00:00, 1674.23it/s]

# %%
# Retrieve evaluations from fens
import logging
import chess
import chess.engine
import numpy as np
from tqdm import tqdm

def get_stockfish_eval_batch(fens, depth=10, threads=6, hash_mb=512, move_time=0.1):
    with chess.engine.SimpleEngine.popen_uci("/usr/games/stockfish") as engine:
        engine.configure({
            "Threads": threads,
            "Hash": hash_mb,
        })
        results = []
        for fen in tqdm(fens, desc="Evaluating FENs with Stockfish"):
            if fen is None:
                results.append(None)
                continue
            board = chess.Board(fen)
            try:
                result = engine.analyse(board, chess.engine.Limit(depth=depth, time=move_time))
                results.append(result["score"])
            except Exception as e:
                logging.warning(f"Error analyzing FEN: {fen} — {e}")
                results.append(None)
        return results

def format_evaluation(score):
    if score is None:
        return None
    if score.is_mate():
        mate_in = score.relative.mate()
        return float("inf") if mate_in > 0 else float("-inf")
    return score.white().score()

def get_readable_eval(score):
    if score is None:
        return "No evaluation"
    if score == float("inf"):
        return "White mates"
    elif score == float("-inf"):
        return "Black mates"
    return f"{score / 100:.2f}"

# Evaluate with Stockfish
sample_df["opening_eval"] = get_stockfish_eval_batch(sample_df["fen_after_15"].tolist())

# Format evaluation
sample_df["opening_eval"] = sample_df["opening_eval"].apply(format_evaluation).apply(get_readable_eval)
sample_df.to_csv("sample_df.csv", index = False)
# Out:
# Evaluating FENs with Stockfish: 100%|██████████| 2488096/2488096 [11:24:45<00:00, 60.56it/s]

# %%
import pandas as pd
import numpy as np

sample_df = pd.read_csv("sample_df.csv")

# Filter data with no check mates and turn numeric columns to numeric
sample_df = sample_df.query(
    "opening_eval not in ['White mates', 'Black mates']"
).copy()
sample_df['WhiteElo'] = pd.to_numeric(sample_df['WhiteElo'])
sample_df['BlackElo'] = pd.to_numeric(sample_df['BlackElo'])
sample_df["opening_eval"] = pd.to_numeric(sample_df["opening_eval"])

# Define the bracket edges (e.g., 0-200, 201-400, ..., up to the max Elo)
sample_df['AvgElo'] = ((sample_df['WhiteElo'] + sample_df['BlackElo']) / 2).astype(int)
max_elo = sample_df['AvgElo'].max()
bracket_step = 200
bracket_edges = list(range(0, int(max_elo) + bracket_step, bracket_step))

# Create labels for the brackets (e.g., "1-200", "201-400", etc.)
bracket_labels = [f"{i+1}-{i+bracket_step}" for i in bracket_edges[:-1]]

# Assign each match to a bracket
sample_df['EloBracket'] = pd.cut(
    sample_df['AvgElo'],
    bins=bracket_edges,
    labels=bracket_labels,
    include_lowest=True
)

# Define conditions
conditions = [
    (sample_df['Result'] == '1-0') & (sample_df['opening_eval'] > 0),
    (sample_df['Result'] == '1-0') | (sample_df['Result'] == '1/2-1/2') & (sample_df['opening_eval'] < 0)
]

# Define corresponding values
choices = ['Advantage Capitalization', 'Resourcefulness']

# Apply conditions
sample_df['conversion_type'] = np.select(conditions, choices, default="Other")

# Data to be used later
conversion_type = sample_df['conversion_type'].value_counts(normalize = True).round(2)
conversion_type_df = conversion_type.reset_index(name='percentage')

proportions = sample_df.groupby('EloBracket')['conversion_type'].value_counts(normalize=True).round(2)
proportions_df = proportions.reset_index(name='percentage')

opening_eval_per_eco = sample_df.groupby('ECO')['opening_eval'].mean().sort_values().round(2)
opening_eval_per_eco_df = opening_eval_per_eco.reset_index(name='evaluation')

popular_openings = sample_df['ECO'].value_counts(normalize=True).round(2)
popular_openings_df = popular_openings.reset_index(name='percentage')

# Save the data to JSON
import json

data = {
    "conversion_type": conversion_type_df.to_dict(orient="records"),
    "opening_eval_per_eco": opening_eval_per_eco_df.to_dict(orient="records"),
    "proportions": proportions_df.to_dict(orient="records"),
    "popular_openings":popular_openings_df.to_dict(orient="records")
}

with open("summary_data.json", "w") as f:
    json.dump(data, f, indent=2)
# Out:
# /tmp/ipykernel_3916/1760889872.py:47: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   proportions = sample_df.groupby('EloBracket')['conversion_type'].value_counts(normalize=True).round(2)

# %%
# Calculate amount of games won when at advantage and disadvantage
def calculate_advantage_conversion(sample_df):
    """
    Calculate:
    1. Percentage of games won when having opening advantage
    2. Percentage of games won/drawn when at opening disadvantage
    
    Parameters:
        sample_df - DataFrame containing chess games with:
             - 'opening_eval': numeric evaluation after opening
             - 'result': game result (1=win, 0.5=draw, 0=loss)
    """
    # Create conditions
    advantage = sample_df['opening_eval'] > 1 # Esse eval é sempre do ponto de vista do jogador. Se preto e ganhando ainda é positivo
    disadvantage = sample_df['opening_eval'] < -1
    won = sample_df['Result'] == '1-0'
    drawn = sample_df['Result'] == '1/2-1/2'
    
    # Calculate stats
    total_advantage = advantage.sum()
    total_disadvantage = disadvantage.sum()
    
    if total_advantage > 0:
        pct_won_when_ahead = (advantage & won).sum() / total_advantage * 100
    else:
        pct_won_when_ahead = 0.0
    
    if total_disadvantage > 0:
        pct_won_or_drawn_when_behind = ((disadvantage & (won | drawn)).sum() / 
                                      total_disadvantage * 100)
    else:
        pct_won_or_drawn_when_behind = 0.0
    
    return {
        'pct_won_when_ahead': float(pct_won_when_ahead.round(2)),
        'pct_won_or_drawn_when_behind': float(pct_won_or_drawn_when_behind.round(2)),
        'games_with_advantage': int(total_advantage),
        'games_with_disadvantage': int(total_disadvantage)
    }

stats = calculate_advantage_conversion(sample_df)
print(f"Win % when ahead: {stats['pct_won_when_ahead']:.1f}%")
print(f"Win/draw % when behind: {stats['pct_won_or_drawn_when_behind']:.1f}%")

opening_eval_per_eco = sample_df.groupby('ECO')['opening_eval'].mean().sort_values().round(2)
opening_eval_per_eco_df = opening_eval_per_eco.reset_index(name='evaluation')

popular_openings = sample_df['ECO'].value_counts(normalize=True).round(4)
popular_openings_df = popular_openings.head().reset_index(name='percentage')

# Save the data to JSON
import json

data = {
    "conversion_stats": calculate_advantage_conversion(sample_df),
    "opening_eval_per_eco": opening_eval_per_eco_df.to_dict(orient="records"),
    "popular_openings":popular_openings_df.to_dict(orient="records")
}

with open("summary_data_lichess_games.json", "w") as f:
    json.dump(data, f, indent=2)
# Out:
# Win % when ahead: 62.8%
# Win/draw % when behind: 34.9%

# %%
# Read the JSON data
import pandas as pd
import json

# Read JSON back into a dictionary
with open("summary_data_lichess_games.json", "r") as f:
    loaded_data = json.load(f)

loaded_data
# Out:
# {'conversion_stats': {'pct_won_when_ahead': 64.79,
#   'pct_won_or_drawn_when_behind': 32.85,
#   'games_with_advantage': 788081,
#   'games_with_disadvantage': 522425},
#  'opening_eval_per_eco': [{'ECO': 'E03', 'evaluation': -1.64},
#   {'ECO': 'E23', 'evaluation': -1.2},
#   {'ECO': 'C38', 'evaluation': -1.09},
#   {'ECO': 'E13', 'evaluation': -0.82},
#   {'ECO': 'D81', 'evaluation': -0.7},
#   {'ECO': 'E29', 'evaluation': -0.64},
#   {'ECO': 'E28', 'evaluation': -0.62},
#   {'ECO': 'B20', 'evaluation': -0.43},
#   {'ECO': 'A98', 'evaluation': -0.37},
#   {'ECO': 'E59', 'evaluation': -0.32},
#   {'ECO': 'C76', 'evaluation': -0.32},
#   {'ECO': 'E78', 'evaluation': -0.28},
#   {'ECO': 'B74', 'evaluation': -0.27},
#   {'ECO': 'B87', 'evaluation': -0.23},
#   {'ECO': 'B49', 'evaluation': -0.23},
#   {'ECO': 'B70', 'evaluation': -0.23},
#   {'ECO': 'E45', 'evaluation': -0.22},
#   {'ECO': 'C37', 'evaluation': -0.21},
#   {'ECO': 'B62', 'evaluation': -0.2},
#   {'ECO': 'D28', 'evaluation': -0.19},
#   {'ECO': 'A89', 'evaluation': -0.16},
#   {'ECO': 'A06', 'evaluation': -0.15},
#   {'ECO': 'C22', 'evaluation': -0.14},
#   {'ECO': 'B95', 'evaluation': -0.14},
#   {'ECO': 'C27', 'evaluation': -0.13},
#   {'ECO': 'B86', 'evaluation': -0.12},
#   {'ECO': 'B10', 'evaluation': -0.11},
#   {'ECO': 'D80', 'evaluation': -0.07},
#   {'ECO': 'E26', 'evaluation': -0.07},
#   {'ECO': 'B34', 'evaluation': -0.07},
#   {'ECO': 'B57', 'evaluation': -0.06},
#   {'ECO': 'B11', 'evaluation': -0.05},
#   {'ECO': 'C35', 'evaluation': -0.04},
#   {'ECO': 'B56', 'evaluation': -0.03},
#   {'ECO': 'E14', 'evaluation': -0.03},
#   {'ECO': 'A96', 'evaluation': -0.02},
#   {'ECO': 'B66', 'evaluation': -0.02},
#   {'ECO': 'C04', 'evaluation': -0.02},
#   {'ECO': 'B84', 'evaluation': -0.02},
#   {'ECO': 'B33', 'evaluation': -0.02},
#   {'ECO': 'B05', 'evaluation': -0.0},
#   {'ECO': 'D48', 'evaluation': -0.0},
#   {'ECO': 'B43', 'evaluation': 0.0},
#   {'ECO': 'B54', 'evaluation': 0.01},
#   {'ECO': 'D91', 'evaluation': 0.01},
#   {'ECO': 'D75', 'evaluation': 0.02},
#   {'ECO': 'C58', 'evaluation': 0.03},
#   {'ECO': 'C63', 'evaluation': 0.05},
#   {'ECO': 'B44', 'evaluation': 0.06},
#   {'ECO': 'B35', 'evaluation': 0.06},
#   {'ECO': 'C89', 'evaluation': 0.06},
#   {'ECO': 'C12', 'evaluation': 0.06},
#   {'ECO': 'C83', 'evaluation': 0.06},
#   {'ECO': 'A00', 'evaluation': 0.06},
#   {'ECO': 'D58', 'evaluation': 0.06},
#   {'ECO': 'A57', 'evaluation': 0.07},
#   {'ECO': 'C31', 'evaluation': 0.07},
#   {'ECO': 'D84', 'evaluation': 0.08},
#   {'ECO': 'C02', 'evaluation': 0.08},
#   {'ECO': 'C20', 'evaluation': 0.08},
#   {'ECO': 'D69', 'evaluation': 0.08},
#   {'ECO': 'D94', 'evaluation': 0.09},
#   {'ECO': 'B85', 'evaluation': 0.09},
#   {'ECO': 'B21', 'evaluation': 0.1},
#   {'ECO': 'A48', 'evaluation': 0.11},
#   {'ECO': 'A99', 'evaluation': 0.11},
#   {'ECO': 'B80', 'evaluation': 0.11},
#   {'ECO': 'E89', 'evaluation': 0.11},
#   {'ECO': 'E31', 'evaluation': 0.12},
#   {'ECO': 'A71', 'evaluation': 0.12},
#   {'ECO': 'A68', 'evaluation': 0.12},
#   {'ECO': 'A51', 'evaluation': 0.12},
#   {'ECO': 'B50', 'evaluation': 0.12},
#   {'ECO': 'D56', 'evaluation': 0.12},
#   {'ECO': 'B96', 'evaluation': 0.13},
#   {'ECO': 'E58', 'evaluation': 0.13},
#   {'ECO': 'B28', 'evaluation': 0.13},
#   {'ECO': 'B73', 'evaluation': 0.13},
#   {'ECO': 'B88', 'evaluation': 0.14},
#   {'ECO': 'B40', 'evaluation': 0.14},
#   {'ECO': 'B30', 'evaluation': 0.14},
#   {'ECO': 'B47', 'evaluation': 0.15},
#   {'ECO': 'A05', 'evaluation': 0.15},
#   {'ECO': 'B23', 'evaluation': 0.15},
#   {'ECO': 'E60', 'evaluation': 0.16},
#   {'ECO': 'B51', 'evaluation': 0.16},
#   {'ECO': 'A45', 'evaluation': 0.17},
#   {'ECO': 'B36', 'evaluation': 0.17},
#   {'ECO': 'A26', 'evaluation': 0.17},
#   {'ECO': 'B13', 'evaluation': 0.17},
#   {'ECO': 'E55', 'evaluation': 0.19},
#   {'ECO': 'C24', 'evaluation': 0.19},
#   {'ECO': 'B29', 'evaluation': 0.19},
#   {'ECO': 'B71', 'evaluation': 0.19},
#   {'ECO': 'A31', 'evaluation': 0.2},
#   {'ECO': 'B92', 'evaluation': 0.2},
#   {'ECO': 'B41', 'evaluation': 0.2},
#   {'ECO': 'E61', 'evaluation': 0.2},
#   {'ECO': 'D87', 'evaluation': 0.21},
#   {'ECO': 'B67', 'evaluation': 0.21},
#   {'ECO': 'D59', 'evaluation': 0.21},
#   {'ECO': 'D47', 'evaluation': 0.21},
#   {'ECO': 'A03', 'evaluation': 0.21},
#   {'ECO': 'E39', 'evaluation': 0.22},
#   {'ECO': 'B83', 'evaluation': 0.22},
#   {'ECO': 'E30', 'evaluation': 0.22},
#   {'ECO': 'E56', 'evaluation': 0.23},
#   {'ECO': 'E64', 'evaluation': 0.23},
#   {'ECO': 'A37', 'evaluation': 0.23},
#   {'ECO': 'A95', 'evaluation': 0.23},
#   {'ECO': 'A56', 'evaluation': 0.24},
#   {'ECO': 'E63', 'evaluation': 0.24},
#   {'ECO': 'D90', 'evaluation': 0.24},
#   {'ECO': 'B90', 'evaluation': 0.24},
#   {'ECO': 'A93', 'evaluation': 0.24},
#   {'ECO': 'B52', 'evaluation': 0.25},
#   {'ECO': 'B97', 'evaluation': 0.25},
#   {'ECO': 'C73', 'evaluation': 0.26},
#   {'ECO': 'B89', 'evaluation': 0.26},
#   {'ECO': 'B39', 'evaluation': 0.26},
#   {'ECO': 'B17', 'evaluation': 0.26},
#   {'ECO': 'B78', 'evaluation': 0.26},
#   {'ECO': 'D85', 'evaluation': 0.26},
#   {'ECO': 'B37', 'evaluation': 0.27},
#   {'ECO': 'B82', 'evaluation': 0.27},
#   {'ECO': 'C91', 'evaluation': 0.27},
#   {'ECO': 'E38', 'evaluation': 0.27},
#   {'ECO': 'D12', 'evaluation': 0.27},
#   {'ECO': 'E66', 'evaluation': 0.28},
#   {'ECO': 'C01', 'evaluation': 0.28},
#   {'ECO': 'E54', 'evaluation': 0.28},
#   {'ECO': 'C71', 'evaluation': 0.28},
#   {'ECO': 'A58', 'evaluation': 0.28},
#   {'ECO': 'B04', 'evaluation': 0.3},
#   {'ECO': 'D51', 'evaluation': 0.3},
#   {'ECO': 'D52', 'evaluation': 0.3},
#   {'ECO': 'E72', 'evaluation': 0.31},
#   {'ECO': 'B42', 'evaluation': 0.32},
#   {'ECO': 'D44', 'evaluation': 0.32},
#   {'ECO': 'C23', 'evaluation': 0.33},
#   {'ECO': 'D93', 'evaluation': 0.33},
#   {'ECO': 'E20', 'evaluation': 0.33},
#   {'ECO': 'A87', 'evaluation': 0.33},
#   {'ECO': 'B27', 'evaluation': 0.34},
#   {'ECO': 'A43', 'evaluation': 0.34},
#   {'ECO': 'B03', 'evaluation': 0.34},
#   {'ECO': 'B08', 'evaluation': 0.34},
#   {'ECO': 'D57', 'evaluation': 0.34},
#   {'ECO': 'A49', 'evaluation': 0.34},
#   {'ECO': 'E36', 'evaluation': 0.34},
#   {'ECO': 'E62', 'evaluation': 0.35},
#   {'ECO': 'A85', 'evaluation': 0.35},
#   {'ECO': 'B26', 'evaluation': 0.35},
#   {'ECO': 'B53', 'evaluation': 0.35},
#   {'ECO': 'D68', 'evaluation': 0.35},
#   {'ECO': 'B19', 'evaluation': 0.35},
#   {'ECO': 'C19', 'evaluation': 0.35},
#   {'ECO': 'A33', 'evaluation': 0.35},
#   {'ECO': 'E21', 'evaluation': 0.36},
#   {'ECO': 'C33', 'evaluation': 0.36},
#   {'ECO': 'C26', 'evaluation': 0.36},
#   {'ECO': 'B25', 'evaluation': 0.37},
#   {'ECO': 'E12', 'evaluation': 0.37},
#   {'ECO': 'D13', 'evaluation': 0.37},
#   {'ECO': 'E24', 'evaluation': 0.37},
#   {'ECO': 'D63', 'evaluation': 0.38},
#   {'ECO': 'A01', 'evaluation': 0.38},
#   {'ECO': 'A47', 'evaluation': 0.38},
#   {'ECO': 'D27', 'evaluation': 0.38},
#   {'ECO': 'A46', 'evaluation': 0.38},
#   {'ECO': 'B65', 'evaluation': 0.38},
#   {'ECO': 'D83', 'evaluation': 0.38},
#   {'ECO': 'C11', 'evaluation': 0.38},
#   {'ECO': 'E27', 'evaluation': 0.38},
#   {'ECO': 'D03', 'evaluation': 0.39},
#   {'ECO': 'E25', 'evaluation': 0.39},
#   {'ECO': 'A84', 'evaluation': 0.39},
#   {'ECO': 'C47', 'evaluation': 0.39},
#   {'ECO': 'D60', 'evaluation': 0.39},
#   {'ECO': 'D89', 'evaluation': 0.4},
#   {'ECO': 'B12', 'evaluation': 0.4},
#   {'ECO': 'E37', 'evaluation': 0.4},
#   {'ECO': 'E00', 'evaluation': 0.4},
#   {'ECO': 'B24', 'evaluation': 0.4},
#   {'ECO': 'C82', 'evaluation': 0.4},
#   {'ECO': 'B46', 'evaluation': 0.41},
#   {'ECO': 'B31', 'evaluation': 0.41},
#   {'ECO': 'A11', 'evaluation': 0.41},
#   {'ECO': 'C88', 'evaluation': 0.41},
#   {'ECO': 'A86', 'evaluation': 0.42},
#   {'ECO': 'D86', 'evaluation': 0.42},
#   {'ECO': 'E41', 'evaluation': 0.42},
#   {'ECO': 'E90', 'evaluation': 0.42},
#   {'ECO': 'C15', 'evaluation': 0.42},
#   {'ECO': 'E11', 'evaluation': 0.42},
#   {'ECO': 'E67', 'evaluation': 0.42},
#   {'ECO': 'B02', 'evaluation': 0.43},
#   {'ECO': 'B91', 'evaluation': 0.43},
#   {'ECO': 'B48', 'evaluation': 0.43},
#   {'ECO': 'E94', 'evaluation': 0.44},
#   {'ECO': 'A69', 'evaluation': 0.44},
#   {'ECO': 'A38', 'evaluation': 0.44},
#   {'ECO': 'A23', 'evaluation': 0.44},
#   {'ECO': 'A76', 'evaluation': 0.45},
#   {'ECO': 'C84', 'evaluation': 0.45},
#   {'ECO': 'C07', 'evaluation': 0.45},
#   {'ECO': 'A78', 'evaluation': 0.45},
#   {'ECO': 'A83', 'evaluation': 0.45},
#   {'ECO': 'C59', 'evaluation': 0.45},
#   {'ECO': 'B58', 'evaluation': 0.45},
#   {'ECO': 'D19', 'evaluation': 0.46},
#   {'ECO': 'D41', 'evaluation': 0.46},
#   {'ECO': 'C17', 'evaluation': 0.46},
#   {'ECO': 'B60', 'evaluation': 0.46},
#   {'ECO': 'A53', 'evaluation': 0.46},
#   {'ECO': 'C00', 'evaluation': 0.47},
#   {'ECO': 'D40', 'evaluation': 0.47},
#   {'ECO': 'D04', 'evaluation': 0.47},
#   {'ECO': 'B72', 'evaluation': 0.47},
#   {'ECO': 'E22', 'evaluation': 0.47},
#   {'ECO': 'D32', 'evaluation': 0.48},
#   {'ECO': 'D53', 'evaluation': 0.48},
#   {'ECO': 'B14', 'evaluation': 0.48},
#   {'ECO': 'C36', 'evaluation': 0.48},
#   {'ECO': 'A80', 'evaluation': 0.48},
#   {'ECO': 'C55', 'evaluation': 0.48},
#   {'ECO': 'A17', 'evaluation': 0.49},
#   {'ECO': 'D14', 'evaluation': 0.49},
#   {'ECO': 'B98', 'evaluation': 0.49},
#   {'ECO': 'A90', 'evaluation': 0.49},
#   {'ECO': 'C21', 'evaluation': 0.5},
#   {'ECO': 'C95', 'evaluation': 0.5},
#   {'ECO': 'E65', 'evaluation': 0.5},
#   {'ECO': 'B18', 'evaluation': 0.5},
#   {'ECO': 'C28', 'evaluation': 0.51},
#   {'ECO': 'B69', 'evaluation': 0.51},
#   {'ECO': 'E35', 'evaluation': 0.51},
#   {'ECO': 'E92', 'evaluation': 0.51},
#   {'ECO': 'B45', 'evaluation': 0.51},
#   {'ECO': 'D34', 'evaluation': 0.51},
#   {'ECO': 'A97', 'evaluation': 0.52},
#   {'ECO': 'C52', 'evaluation': 0.52},
#   {'ECO': 'B22', 'evaluation': 0.52},
#   {'ECO': 'D79', 'evaluation': 0.52},
#   {'ECO': 'E93', 'evaluation': 0.52},
#   {'ECO': 'A14', 'evaluation': 0.53},
#   {'ECO': 'D55', 'evaluation': 0.53},
#   {'ECO': 'B06', 'evaluation': 0.53},
#   {'ECO': 'B94', 'evaluation': 0.53},
#   {'ECO': 'D00', 'evaluation': 0.53},
#   {'ECO': 'E19', 'evaluation': 0.53},
#   {'ECO': 'E51', 'evaluation': 0.54},
#   {'ECO': 'C46', 'evaluation': 0.54},
#   {'ECO': 'C45', 'evaluation': 0.54},
#   {'ECO': 'D54', 'evaluation': 0.54},
#   {'ECO': 'E52', 'evaluation': 0.54},
#   {'ECO': 'D78', 'evaluation': 0.54},
#   {'ECO': 'C50', 'evaluation': 0.55},
#   {'ECO': 'D42', 'evaluation': 0.55},
#   {'ECO': 'B61', 'evaluation': 0.55},
#   {'ECO': 'A02', 'evaluation': 0.55},
#   {'ECO': 'B68', 'evaluation': 0.55},
#   {'ECO': 'C14', 'evaluation': 0.56},
#   {'ECO': 'C08', 'evaluation': 0.56},
#   {'ECO': 'A88', 'evaluation': 0.56},
#   {'ECO': 'B59', 'evaluation': 0.56},
#   {'ECO': 'C13', 'evaluation': 0.56},
#   {'ECO': 'E70', 'evaluation': 0.56},
#   {'ECO': 'E18', 'evaluation': 0.56},
#   {'ECO': 'C68', 'evaluation': 0.56},
#   {'ECO': 'A16', 'evaluation': 0.56},
#   {'ECO': 'E33', 'evaluation': 0.57},
#   {'ECO': 'A64', 'evaluation': 0.57},
#   {'ECO': 'A15', 'evaluation': 0.57},
#   {'ECO': 'D66', 'evaluation': 0.58},
#   {'ECO': 'E97', 'evaluation': 0.58},
#   {'ECO': 'A35', 'evaluation': 0.58},
#   {'ECO': 'C96', 'evaluation': 0.58},
#   {'ECO': 'B32', 'evaluation': 0.58},
#   {'ECO': 'D05', 'evaluation': 0.58},
#   {'ECO': 'C18', 'evaluation': 0.59},
#   {'ECO': 'D45', 'evaluation': 0.59},
#   {'ECO': 'E34', 'evaluation': 0.59},
#   {'ECO': 'B01', 'evaluation': 0.59},
#   {'ECO': 'A08', 'evaluation': 0.59},
#   {'ECO': 'D88', 'evaluation': 0.6},
#   {'ECO': 'A30', 'evaluation': 0.6},
#   {'ECO': 'E43', 'evaluation': 0.6},
#   {'ECO': 'D70', 'evaluation': 0.6},
#   {'ECO': 'D15', 'evaluation': 0.6},
#   {'ECO': 'C80', 'evaluation': 0.61},
#   {'ECO': 'E08', 'evaluation': 0.61},
#   {'ECO': 'A28', 'evaluation': 0.62},
#   {'ECO': 'E16', 'evaluation': 0.62},
#   {'ECO': 'B15', 'evaluation': 0.62},
#   {'ECO': 'D10', 'evaluation': 0.62},
#   {'ECO': 'E05', 'evaluation': 0.62},
#   {'ECO': 'D96', 'evaluation': 0.63},
#   {'ECO': 'A63', 'evaluation': 0.63},
#   {'ECO': 'E50', 'evaluation': 0.63},
#   {'ECO': 'D77', 'evaluation': 0.63},
#   {'ECO': 'C94', 'evaluation': 0.63},
#   {'ECO': 'D95', 'evaluation': 0.63},
#   {'ECO': 'A12', 'evaluation': 0.64},
#   {'ECO': 'C85', 'evaluation': 0.65},
#   {'ECO': 'B00', 'evaluation': 0.65},
#   {'ECO': 'E32', 'evaluation': 0.65},
#   {'ECO': 'D35', 'evaluation': 0.65},
#   {'ECO': 'C69', 'evaluation': 0.65},
#   {'ECO': 'D67', 'evaluation': 0.65},
#   {'ECO': 'D64', 'evaluation': 0.66},
#   {'ECO': 'C99', 'evaluation': 0.66},
#   {'ECO': 'E53', 'evaluation': 0.66},
#   {'ECO': 'D17', 'evaluation': 0.66},
#   {'ECO': 'C54', 'evaluation': 0.66},
#   {'ECO': 'A82', 'evaluation': 0.66},
#   {'ECO': 'A59', 'evaluation': 0.66},
#   {'ECO': 'B93', 'evaluation': 0.67},
#   {'ECO': 'E85', 'evaluation': 0.67},
#   {'ECO': 'A36', 'evaluation': 0.68},
#   {'ECO': 'A81', 'evaluation': 0.68},
#   {'ECO': 'A50', 'evaluation': 0.68},
#   {'ECO': 'B07', 'evaluation': 0.68},
#   {'ECO': 'E84', 'evaluation': 0.68},
#   {'ECO': 'C48', 'evaluation': 0.68},
#   {'ECO': 'C49', 'evaluation': 0.68},
#   {'ECO': 'E68', 'evaluation': 0.68},
#   {'ECO': 'A52', 'evaluation': 0.68},
#   {'ECO': 'C90', 'evaluation': 0.68},
#   {'ECO': 'C56', 'evaluation': 0.68},
#   {'ECO': 'A44', 'evaluation': 0.68},
#   {'ECO': 'D61', 'evaluation': 0.68},
#   {'ECO': 'C92', 'evaluation': 0.68},
#   {'ECO': 'A70', 'evaluation': 0.69},
#   {'ECO': 'A41', 'evaluation': 0.69},
#   {'ECO': 'A04', 'evaluation': 0.69},
#   {'ECO': 'C10', 'evaluation': 0.7},
#   {'ECO': 'D92', 'evaluation': 0.7},
#   {'ECO': 'E17', 'evaluation': 0.7},
#   {'ECO': 'C77', 'evaluation': 0.7},
#   {'ECO': 'D01', 'evaluation': 0.7},
#   {'ECO': 'A54', 'evaluation': 0.7},
#   {'ECO': 'C97', 'evaluation': 0.7},
#   {'ECO': 'A07', 'evaluation': 0.71},
#   {'ECO': 'E46', 'evaluation': 0.71},
#   {'ECO': 'D30', 'evaluation': 0.71},
#   {'ECO': 'C67', 'evaluation': 0.71},
#   {'ECO': 'A61', 'evaluation': 0.71},
#   {'ECO': 'D43', 'evaluation': 0.72},
#   {'ECO': 'D33', 'evaluation': 0.72},
#   {'ECO': 'D82', 'evaluation': 0.72},
#   {'ECO': 'A55', 'evaluation': 0.73},
#   {'ECO': 'E71', 'evaluation': 0.73},
#   {'ECO': 'B99', 'evaluation': 0.73},
#   {'ECO': 'E10', 'evaluation': 0.73},
#   {'ECO': 'D02', 'evaluation': 0.73},
#   {'ECO': 'E15', 'evaluation': 0.73},
#   {'ECO': 'A91', 'evaluation': 0.73},
#   {'ECO': 'E07', 'evaluation': 0.74},
#   {'ECO': 'C44', 'evaluation': 0.74},
#   {'ECO': 'A34', 'evaluation': 0.74},
#   {'ECO': 'E98', 'evaluation': 0.74},
#   {'ECO': 'D11', 'evaluation': 0.74},
#   {'ECO': 'E95', 'evaluation': 0.74},
#   {'ECO': 'A32', 'evaluation': 0.75},
#   {'ECO': 'D71', 'evaluation': 0.75},
#   {'ECO': 'B09', 'evaluation': 0.75},
#   {'ECO': 'A29', 'evaluation': 0.75},
#   {'ECO': 'C72', 'evaluation': 0.75},
#   {'ECO': 'A42', 'evaluation': 0.75},
#   {'ECO': 'E42', 'evaluation': 0.76},
#   {'ECO': 'A19', 'evaluation': 0.76},
#   {'ECO': 'E75', 'evaluation': 0.76},
#   {'ECO': 'E81', 'evaluation': 0.76},
#   {'ECO': 'A39', 'evaluation': 0.78},
#   {'ECO': 'D39', 'evaluation': 0.78},
#   {'ECO': 'A22', 'evaluation': 0.78},
#   {'ECO': 'E80', 'evaluation': 0.78},
#   {'ECO': 'A13', 'evaluation': 0.79},
#   {'ECO': 'E76', 'evaluation': 0.79},
#   {'ECO': 'C05', 'evaluation': 0.8},
#   {'ECO': 'C61', 'evaluation': 0.8},
#   {'ECO': 'D46', 'evaluation': 0.8},
#   {'ECO': 'E40', 'evaluation': 0.8},
#   {'ECO': 'A75', 'evaluation': 0.81},
#   {'ECO': 'E48', 'evaluation': 0.81},
#   {'ECO': 'D37', 'evaluation': 0.82},
#   {'ECO': 'A40', 'evaluation': 0.82},
#   {'ECO': 'C43', 'evaluation': 0.82},
#   {'ECO': 'E06', 'evaluation': 0.82},
#   {'ECO': 'C41', 'evaluation': 0.84},
#   {'ECO': 'C06', 'evaluation': 0.85},
#   {'ECO': 'E47', 'evaluation': 0.86},
#   {'ECO': 'A20', 'evaluation': 0.86},
#   {'ECO': 'A62', 'evaluation': 0.86},
#   {'ECO': 'D98', 'evaluation': 0.86},
#   {'ECO': 'C32', 'evaluation': 0.86},
#   {'ECO': 'B64', 'evaluation': 0.86},
#   {'ECO': 'C42', 'evaluation': 0.87},
#   {'ECO': 'B38', 'evaluation': 0.87},
#   {'ECO': 'C86', 'evaluation': 0.87},
#   {'ECO': 'C62', 'evaluation': 0.88},
#   {'ECO': 'A92', 'evaluation': 0.88},
#   {'ECO': 'E01', 'evaluation': 0.88},
#   {'ECO': 'C25', 'evaluation': 0.88},
#   {'ECO': 'C64', 'evaluation': 0.88},
#   {'ECO': 'C30', 'evaluation': 0.89},
#   {'ECO': 'B16', 'evaluation': 0.89},
#   {'ECO': 'E77', 'evaluation': 0.89},
#   {'ECO': 'A67', 'evaluation': 0.9},
#   {'ECO': 'C39', 'evaluation': 0.9},
#   {'ECO': 'E74', 'evaluation': 0.9},
#   {'ECO': 'E87', 'evaluation': 0.9},
#   {'ECO': 'E99', 'evaluation': 0.9},
#   {'ECO': 'C09', 'evaluation': 0.9},
#   {'ECO': 'C34', 'evaluation': 0.9},
#   {'ECO': 'B76', 'evaluation': 0.91},
#   {'ECO': 'D08', 'evaluation': 0.91},
#   {'ECO': 'E83', 'evaluation': 0.91},
#   {'ECO': 'A25', 'evaluation': 0.92},
#   {'ECO': 'B77', 'evaluation': 0.92},
#   {'ECO': 'A24', 'evaluation': 0.93},
#   {'ECO': 'E73', 'evaluation': 0.93},
#   {'ECO': 'A10', 'evaluation': 0.94},
#   {'ECO': 'A73', 'evaluation': 0.94},
#   {'ECO': 'D74', 'evaluation': 0.94},
#   {'ECO': 'D97', 'evaluation': 0.94},
#   {'ECO': 'E91', 'evaluation': 0.95},
#   {'ECO': 'C53', 'evaluation': 0.95},
#   {'ECO': 'A60', 'evaluation': 0.96},
#   {'ECO': 'A65', 'evaluation': 0.96},
#   {'ECO': 'C93', 'evaluation': 0.97},
#   {'ECO': 'D50', 'evaluation': 0.97},
#   {'ECO': 'B75', 'evaluation': 0.98},
#   {'ECO': 'C79', 'evaluation': 0.98},
#   {'ECO': 'C70', 'evaluation': 0.98},
#   {'ECO': 'E04', 'evaluation': 0.98},
#   {'ECO': 'B63', 'evaluation': 0.99},
#   {'ECO': 'B55', 'evaluation': 0.99},
#   {'ECO': 'E86', 'evaluation': 1.0},
#   {'ECO': 'A09', 'evaluation': 1.0},
#   {'ECO': 'C51', 'evaluation': 1.01},
#   {'ECO': 'C03', 'evaluation': 1.01},
#   {'ECO': 'C66', 'evaluation': 1.01},
#   {'ECO': 'B79', 'evaluation': 1.02},
#   {'ECO': 'C78', 'evaluation': 1.02},
#   {'ECO': 'C75', 'evaluation': 1.02},
#   {'ECO': 'A27', 'evaluation': 1.02},
#   {'ECO': 'C74', 'evaluation': 1.02},
#   {'ECO': 'D18', 'evaluation': 1.03},
#   {'ECO': 'C65', 'evaluation': 1.03},
#   {'ECO': 'A18', 'evaluation': 1.03},
#   {'ECO': 'D31', 'evaluation': 1.03},
#   {'ECO': 'D38', 'evaluation': 1.04},
#   {'ECO': 'C60', 'evaluation': 1.05},
#   {'ECO': 'D26', 'evaluation': 1.06},
#   {'ECO': 'D36', 'evaluation': 1.06},
#   {'ECO': 'E69', 'evaluation': 1.1},
#   {'ECO': 'C98', 'evaluation': 1.1},
#   {'ECO': 'E44', 'evaluation': 1.11},
#   {'ECO': 'A94', 'evaluation': 1.11},
#   {'ECO': 'D09', 'evaluation': 1.12},
#   {'ECO': 'C16', 'evaluation': 1.14},
#   {'ECO': 'A21', 'evaluation': 1.16},
#   {'ECO': 'A72', 'evaluation': 1.17},
#   {'ECO': 'E79', 'evaluation': 1.17},
#   {'ECO': 'D06', 'evaluation': 1.21},
#   {'ECO': 'D23', 'evaluation': 1.22},
#   {'ECO': 'C57', 'evaluation': 1.23},
#   {'ECO': 'C87', 'evaluation': 1.24},
#   {'ECO': 'D24', 'evaluation': 1.25},
#   {'ECO': 'E02', 'evaluation': 1.25},
#   {'ECO': 'A66', 'evaluation': 1.26},
#   {'ECO': 'E09', 'evaluation': 1.26},
#   {'ECO': 'A77', 'evaluation': 1.27},
#   {'ECO': 'E82', 'evaluation': 1.3},
#   {'ECO': 'A74', 'evaluation': 1.34},
#   {'ECO': 'E49', 'evaluation': 1.35},
#   {'ECO': 'D20', 'evaluation': 1.37},
#   {'ECO': 'D16', 'evaluation': 1.38},
#   {'ECO': 'D22', 'evaluation': 1.39},
#   {'ECO': 'D25', 'evaluation': 1.44},
#   {'ECO': 'D29', 'evaluation': 1.47},
#   {'ECO': 'B81', 'evaluation': 1.49},
#   {'ECO': 'C40', 'evaluation': 1.5},
#   {'ECO': 'C29', 'evaluation': 1.51},
#   {'ECO': 'D21', 'evaluation': 1.53},
#   {'ECO': 'D07', 'evaluation': 1.57},
#   {'ECO': 'C81', 'evaluation': 1.65},
#   {'ECO': 'E96', 'evaluation': 1.7},
#   {'ECO': 'D76', 'evaluation': 1.73},
#   {'ECO': 'A79', 'evaluation': 2.89}],
#  'popular_openings': [{'ECO': 'A00', 'percentage': 0.0637},
#   {'ECO': 'A40', 'percentage': 0.0579},
#   {'ECO': 'B01', 'percentage': 0.0543},
#   {'ECO': 'B00', 'percentage': 0.046},
#   {'ECO': 'D00', 'percentage': 0.0427}]}
